# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("survey_results_public.csv" , index_col="Respondent")

# %%
df.head()
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
#
#            Age1stCode CompFreq  CompTotal  ConvertedComp             Country  \
# Respondent
# 1                  13  Monthly        NaN            NaN             Germany
# 2                  19      NaN        NaN            NaN      United Kingdom
# 3                  15      NaN        NaN            NaN  Russian Federation
# 4                  18      NaN        NaN            NaN             Albania
# 5                  16      NaN        NaN            NaN       United States
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 64461 entries, 1 to 65112
# Data columns (total 60 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   MainBranch                    64162 non-null  object
#  1   Hobbyist                      64416 non-null  object
#  2   Age                           45446 non-null  float64
#  3   Age1stCode                    57900 non-null  object
#  4   CompFreq                      40069 non-null  object
#  5   CompTotal                     34826 non-null  float64
#  6   ConvertedComp                 34756 non-null  float64
#  7   Country                       64072 non-null  object
#  8   CurrencyDesc                  45472 non-null  object
#  9   CurrencySymbol                45472 non-null  object
#  10  DatabaseDesireNextYear        44070 non-null  object
#  11  DatabaseWorkedWith            49537 non-null  object
# ...

# %%
df.describe()
# Out:
#                 Age      CompTotal  ConvertedComp   WorkWeekHrs
# count  45446.000000   3.482600e+04   3.475600e+04  41151.000000
# mean      30.834111  3.190464e+242   1.037561e+05     40.782174
# std        9.585392            inf   2.268853e+05     17.816383
# min        1.000000   0.000000e+00   0.000000e+00      1.000000
# 25%       24.000000   2.000000e+04   2.464800e+04     40.000000
# 50%       29.000000   6.300000e+04   5.404900e+04     40.000000
# 75%       35.000000   1.250000e+05   9.500000e+04     44.000000
# max      279.000000  1.111111e+247   2.000000e+06    475.000000

# %%
df
# Out:
#                                                    MainBranch Hobbyist   Age  \
# Respondent
# 1                              I am a developer by profession      Yes   NaN
# 2                              I am a developer by profession       No   NaN
# 3                                 I code primarily as a hobby      Yes   NaN
# 4                              I am a developer by profession      Yes  25.0
# 5           I used to be a developer by profession, but no...      Yes  31.0
# ...                                                       ...      ...   ...
# 64858                                                     NaN      Yes   NaN
# 64867                                                     NaN      Yes   NaN
# 64898                                                     NaN      Yes   NaN
# 64925                                                     NaN      Yes   NaN
# 65112                                                     NaN      Yes   NaN
#
# ...

# %%
# Les colonnes sur lesquelles je travaille
df.columns[45::]
# Out:
# Index(['Sexuality', 'SOAccount', 'SOComm', 'SOPartFreq', 'SOVisitFreq',
#        'SurveyEase', 'SurveyLength', 'Trans', 'UndergradMajor',
#        'WebframeDesireNextYear', 'WebframeWorkedWith', 'WelcomeChange',
#        'WorkWeekHrs', 'YearsCode', 'YearsCodePro'],
#       dtype='object')

# %%
# Les différentes valeurs présentes sur la colonne 'Sexuality' avant modfis
pd.unique(df['Sexuality'].values)
# Out:
# array(['Straight / Heterosexual', nan, 'Gay or Lesbian', 'Queer',
#        'Bisexual;Straight / Heterosexual', 'Bisexual', 'Bisexual;Queer',
#        'Gay or Lesbian;Queer',
#        'Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer',
#        'Bisexual;Straight / Heterosexual;Queer',
#        'Bisexual;Gay or Lesbian', 'Straight / Heterosexual;Queer',
#        'Bisexual;Gay or Lesbian;Straight / Heterosexual',
#        'Gay or Lesbian;Straight / Heterosexual',
#        'Bisexual;Gay or Lesbian;Queer'], dtype=object)

# %%
# Changer tous les NAN par 'Other'
df['Sexuality'].fillna('Other' , inplace= True)

# %%
# Quelques modifs sur les valeurs pour les rendres plus lisibles, et leur donner du sens 
# (changer Straight / Heterosexual ==>  Straight)


df['Sexuality'].replace(to_replace='Straight / Heterosexual' , value = 'Straight' , inplace=True)

df['Sexuality'].replace(to_replace='Gay or Lesbian' , value = 'Homosexual' , inplace=True)

# %%
# Les différentes valeurs présentes sur la colonne 'Sexuality' après modfis

pd.unique(df['Sexuality'].values)
# Out:
# array(['Straight', 'Other', 'Homosexual', 'Queer',
#        'Bisexual;Straight / Heterosexual', 'Bisexual', 'Bisexual;Queer',
#        'Gay or Lesbian;Queer',
#        'Bisexual;Gay or Lesbian;Straight / Heterosexual;Queer',
#        'Bisexual;Straight / Heterosexual;Queer',
#        'Bisexual;Gay or Lesbian', 'Straight / Heterosexual;Queer',
#        'Bisexual;Gay or Lesbian;Straight / Heterosexual',
#        'Gay or Lesbian;Straight / Heterosexual',
#        'Bisexual;Gay or Lesbian;Queer'], dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'SOAccount' avant modfis

pd.unique(df['SOAccount'])
# Out:
# array(['No', 'Yes', nan, "Not sure/can't remember"], dtype=object)

# %%
# Changer tous les NAN par 'Other'
df['SOAccount'].fillna('Not mentionned' , inplace= True)

# %%
# Les différentes valeurs présentes sur la colonne 'SOAccount' après modfis

pd.unique(df['SOAccount'])
# Out:
# array(['No', 'Yes', 'Not mentionned', "Not sure/can't remember"],
#       dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'SOComm' avant modfis

pd.unique(df['SOComm'])
# Out:
# array(['No, not at all', 'Yes, definitely', 'Yes, somewhat',
#        'No, not really', 'Neutral', nan, 'Not sure'], dtype=object)

# %%
df['SOComm'].fillna('Not mentionned' , inplace= True)

# %%
# Les différentes valeurs présentes sur la colonne 'SOAccount' après modfis

pd.unique(df['SOComm'])
# Out:
# array(['No, not at all', 'Yes, definitely', 'Yes, somewhat',
#        'No, not really', 'Neutral', 'Not mentionned', 'Not sure'],
#       dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'SOPartFreq' avant modfis

pd.unique(df['SOPartFreq'])
# Out:
# array([nan, 'Less than once per month or monthly',
#        'A few times per month or weekly', 'Multiple times per day',
#        'I have never participated in Q&A on Stack Overflow',
#        'A few times per week', 'Daily or almost daily'], dtype=object)

# %%
df['SOPartFreq'].fillna('Not mentionned' , inplace= True)

# %%
# Les différentes valeurs présentes sur la colonne 'SOAccount' après modfis

pd.unique(df['SOPartFreq'])
# Out:
# array(['Not mentionned', 'Less than once per month or monthly',
#        'A few times per month or weekly', 'Multiple times per day',
#        'I have never participated in Q&A on Stack Overflow',
#        'A few times per week', 'Daily or almost daily'], dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'SOVisitFreq' avant modfis

pd.unique(df['SOVisitFreq'])
# Out:
# array(['Multiple times per day', 'Daily or almost daily',
#        'A few times per month or weekly', 'A few times per week',
#        'I have never visited Stack Overflow (before today)', nan,
#        'Less than once per month or monthly'], dtype=object)

# %%
df['SOVisitFreq'].fillna('Not mentionned' , inplace= True)

# %%
# Les différentes valeurs présentes sur la colonne 'SOVisitFreq' après modfis

pd.unique(df['SOVisitFreq'])
# Out:
# array(['Multiple times per day', 'Daily or almost daily',
#        'A few times per month or weekly', 'A few times per week',
#        'I have never visited Stack Overflow (before today)',
#        'Not mentionned', 'Less than once per month or monthly'],
#       dtype=object)

# %%
# Suppression de la colonne 'SurveyEase' car elle n'aura aucun impact sur notre étude
df.drop(columns= 'SurveyEase' , inplace= True)

# %%
# Suppression de la colonne 'SurveyLength' car elle n'aura aucun impact sur notre étude
df.drop(columns= 'SurveyLength' , inplace= True)

# %%
# Les différentes valeurs présentes sur la colonne 'Trans' avant modfis

pd.unique(df['Trans'])
# Out:
# array(['No', nan, 'Yes'], dtype=object)

# %%
df['Trans'].fillna('Not mentionned' , inplace= True)

# %%
# Les différentes valeurs présentes sur la colonne 'Trans' après modfis

pd.unique(df['Trans'])
# Out:
# array(['No', 'Not mentionned', 'Yes'], dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'UndergradMajor' avant modfis

pd.unique(df['UndergradMajor'])
# Out:
# array(['Computer science, computer engineering, or software engineering',
#        nan, 'Mathematics or statistics',
#        'Another engineering discipline (such as civil, electrical, mechanical, etc.)',
#        'A humanities discipline (such as literature, history, philosophy, etc.)',
#        'A health science (such as nursing, pharmacy, radiology, etc.)',
#        'Information systems, information technology, or system administration',
#        'Web development or web design',
#        'A natural science (such as biology, chemistry, physics, etc.)',
#        'Fine arts or performing arts (such as graphic design, music, studio art, etc.)',
#        'I never declared a major',
#        'A social science (such as anthropology, psychology, political science, etc.)',
#        'A business discipline (such as accounting, finance, marketing, etc.)'],
#       dtype=object)

# %%
df['UndergradMajor'].fillna('Not mentionned' , inplace= True)

# %%
# Les différentes valeurs présentes sur la colonne 'UndergradMajor' après modfis

pd.unique(df['UndergradMajor'])
# Out:
# array(['Computer science, computer engineering, or software engineering',
#        'Not mentionned', 'Mathematics or statistics',
#        'Another engineering discipline (such as civil, electrical, mechanical, etc.)',
#        'A humanities discipline (such as literature, history, philosophy, etc.)',
#        'A health science (such as nursing, pharmacy, radiology, etc.)',
#        'Information systems, information technology, or system administration',
#        'Web development or web design',
#        'A natural science (such as biology, chemistry, physics, etc.)',
#        'Fine arts or performing arts (such as graphic design, music, studio art, etc.)',
#        'I never declared a major',
#        'A social science (such as anthropology, psychology, political science, etc.)',
#        'A business discipline (such as accounting, finance, marketing, etc.)'],
#       dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'WebframeDesireNextYear' avant modfis

pd.unique(df['WebframeDesireNextYear'])
# Out:
# array(['ASP.NET Core', nan, 'Django;Ruby on Rails', ...,
#        'Django;Express;Flask;Gatsby;jQuery;Laravel;React.js;Ruby on Rails;Spring;Vue.js',
#        'ASP.NET;ASP.NET Core;Flask;Gatsby;jQuery;React.js;Vue.js',
#        'Drupal;Flask;Gatsby;Spring;Vue.js'], dtype=object)

# %%
df['WebframeDesireNextYear'].fillna('Not mentionned' , inplace = True)

# %%
# Les différentes valeurs présentes sur la colonne 'WebframeDesireNextYear' après modfis

pd.unique(df['WebframeDesireNextYear'])
# Out:
# array(['ASP.NET Core', 'Not mentionned', 'Django;Ruby on Rails', ...,
#        'Django;Express;Flask;Gatsby;jQuery;Laravel;React.js;Ruby on Rails;Spring;Vue.js',
#        'ASP.NET;ASP.NET Core;Flask;Gatsby;jQuery;React.js;Vue.js',
#        'Drupal;Flask;Gatsby;Spring;Vue.js'], dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'WebframeWorkedWith' avant modfis

pd.unique(df['WebframeWorkedWith'])
# Out:
# array(['ASP.NET;ASP.NET Core', nan, 'Ruby on Rails', ...,
#        'ASP.NET;ASP.NET Core;Flask;Gatsby;jQuery;React.js;Vue.js',
#        'Angular;Angular.js;ASP.NET;ASP.NET Core;Django;Express;jQuery;Laravel;React.js;Ruby on Rails;Symfony',
#        'ASP.NET;ASP.NET Core;Django;jQuery;Symfony;Vue.js'], dtype=object)

# %%
df['WebframeWorkedWith'].fillna('Not mentionned' , inplace = True)

# %%
# Les différentes valeurs présentes sur la colonne 'WebframeWorkedWith' après modfis

pd.unique(df['WebframeWorkedWith'])
# Out:
# array(['ASP.NET;ASP.NET Core', 'Not mentionned', 'Ruby on Rails', ...,
#        'ASP.NET;ASP.NET Core;Flask;Gatsby;jQuery;React.js;Vue.js',
#        'Angular;Angular.js;ASP.NET;ASP.NET Core;Django;Express;jQuery;Laravel;React.js;Ruby on Rails;Symfony',
#        'ASP.NET;ASP.NET Core;Django;jQuery;Symfony;Vue.js'], dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'WelcomeChange' avant modfis

pd.unique(df['WelcomeChange'])
# Out:
# array(['Just as welcome now as I felt last year',
#        'Somewhat more welcome now than last year',
#        'Somewhat less welcome now than last year', nan,
#        'A lot more welcome now than last year',
#        'A lot less welcome now than last year',
#        'Not applicable - I did not use Stack Overflow last year'],
#       dtype=object)

# %%
df['WelcomeChange'].fillna('Not mentionned' , inplace = True)

# %%
# Les différentes valeurs présentes sur la colonne 'WelcomeChange' après modfis

pd.unique(df['WelcomeChange'])
# Out:
# array(['Just as welcome now as I felt last year',
#        'Somewhat more welcome now than last year',
#        'Somewhat less welcome now than last year', 'Not mentionned',
#        'A lot more welcome now than last year',
#        'A lot less welcome now than last year',
#        'Not applicable - I did not use Stack Overflow last year'],
#       dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'WorkWeekHrs' avant modfis
# j'ai changé toutes les valeurs > 168 ==> 168 car il n'y a pas plus de 168 heure dans une semaine

pd.unique(df['WorkWeekHrs'])
# Out:
# array([ 50.        ,          nan,  40.        ,  39.        ,
#         36.        ,  45.        ,  35.        ,  42.        ,
#         37.        ,  30.        ,   5.        ,  43.        ,
#         60.        ,  24.        ,  25.        ,  16.        ,
#         32.        ,  38.        ,  55.        ,  20.        ,
#         70.        ,  37.5       ,  47.        ,  44.        ,
#         72.        ,   8.        ,  12.        ,  41.        ,
#         90.        ,  27.        ,  48.        ,   4.        ,
#         22.        ,  80.        ,  10.        ,  52.        ,
#          8.5       , 120.        ,   9.        ,  15.        ,
#         39.5       ,   6.        ,  54.        ,  40.5       ,
#         46.        ,  18.        , 105.        ,  42.5       ,
#        375.        ,  65.        ,  11.        ,  56.        ,
#         75.        ,  49.        ,  95.        ,  28.        ,
#         35.5       ,  33.        ,  43.5       ,   7.        ,
# ...

# %%
df.loc[(df.WorkWeekHrs > 168) , 'WorkWeekHrs'] = 168

# %%
# Les différentes valeurs présentes sur la colonne 'WorkWeekHrs' après modfis

pd.unique(df['WorkWeekHrs'])
# Out:
# array([ 50.        ,          nan,  40.        ,  39.        ,
#         36.        ,  45.        ,  35.        ,  42.        ,
#         37.        ,  30.        ,   5.        ,  43.        ,
#         60.        ,  24.        ,  25.        ,  16.        ,
#         32.        ,  38.        ,  55.        ,  20.        ,
#         70.        ,  37.5       ,  47.        ,  44.        ,
#         72.        ,   8.        ,  12.        ,  41.        ,
#         90.        ,  27.        ,  48.        ,   4.        ,
#         22.        ,  80.        ,  10.        ,  52.        ,
#          8.5       , 120.        ,   9.        ,  15.        ,
#         39.5       ,   6.        ,  54.        ,  40.5       ,
#         46.        ,  18.        , 105.        ,  42.5       ,
#        168.        ,  65.        ,  11.        ,  56.        ,
#         75.        ,  49.        ,  95.        ,  28.        ,
#         35.5       ,  33.        ,  43.5       ,   7.        ,
# ...

# %%
# Les différentes valeurs présentes sur la colonne 'YearsCode' avant modfis
#pas de modifs a faire les données sont propres
pd.unique(df['YearsCode'])
# Out:
# array(['36', '7', '4', '15', '6', '17', '8', '10', '35', '5', '37', '19',
#        '9', '22', '30', '23', '20', '2', 'Less than 1 year', '3', '13',
#        '25', '16', '43', '11', '38', '33', nan, '24', '21', '12', '40',
#        '27', '50', '46', '14', '18', '28', '32', '44', '26', '42', '31',
#        '34', '29', '1', '39', '41', '45', 'More than 50 years', '47',
#        '49', '48'], dtype=object)

# %%
# Les différentes valeurs présentes sur la colonne 'YearsCodePro' avant modfis
#pas de modifs a faire les données sont propres
pd.unique(df['YearsCodePro'])
# Out:
# array(['27', '4', nan, '8', '13', '2', '7', '20', '1', '23', '3', '12',
#        '17', '18', '10', '14', '29', '6', '28', '9', '15', '11', '16',
#        '25', 'Less than 1 year', '5', '21', '19', '35', '24', '32', '22',
#        '30', '38', '26', '40', '33', '31', 'More than 50 years', '34',
#        '36', '39', '37', '41', '45', '47', '42', '46', '50', '43', '44',
#        '48', '49'], dtype=object)

# %%
df.loc[:, "Ethnicity"].replace(np.NaN, "Unspecified", inplace=True)
df.loc[:, "Gender"].replace(np.NaN, "Unspecified", inplace=True)
df.loc[:, "JobFactors"].replace(np.NaN, "None", inplace=True)
df.loc[:, "JobSat"].replace(np.NaN, "None", inplace=True)
df.loc[:, "JobSeek"].replace(np.NaN, "None", inplace=True)
df.loc[:, "LanguageDesireNextYear"].replace(np.NaN, "None", inplace=True)
df.loc[:, "LanguageWorkedWith"].replace(np.NaN, "None", inplace=True)
df.loc[:, "MiscTechDesireNextYear"].replace(np.NaN, "None", inplace=True)
df.loc[:, "MiscTechWorkedWith"].replace(np.NaN, "None", inplace=True)
df.loc[:, "NEWCollabToolsDesireNextYear"].replace(np.NaN, "None", inplace=True)
df.loc[:, "NEWCollabToolsWorkedWith"].replace(np.NaN, "None", inplace=True)
df.loc[:, "NEWDevOps"].replace(np.NaN, "None", inplace=True)
df.loc[:, "NEWDevOpsImpt"].replace(np.NaN, "None", inplace=True)
df.loc[:, "NEWEdImpt"].replace(np.NaN, "None", inplace=True)
df.loc[:, "NEWJobHunt"].replace(np.NaN, "None", inplace=True)

# %%
df['MainBranch'].replace(to_replace = np.NaN, value = "unspecified", inplace = True)
df['Age'].replace(to_replace = np.NaN, value = "unspecified", inplace = True)
df['Age1stCode'].replace(to_replace = np.NaN, value = "unspecified", inplace = True)
df['Age1stCode'].replace(to_replace = "Younger than 5 years", value = "3", inplace = True)
df['Age1stCode'].replace(to_replace = "Older than 85", value = 85, inplace = True)
df['CompFreq'].replace(to_replace = np.NaN, value = "undefined", inplace = True)
df['CompTotal'].replace(to_replace = np.NaN, value = "undefined", inplace = True)
df['ConvertedComp'].replace(to_replace = np.NaN, value = "none", inplace = True)
df['CurrencyDesc'].replace(to_replace = np.NaN, value = "undefined", inplace = True)
df['CurrencySymbol'].replace(to_replace = np.NaN, value = "undefined", inplace = True)
df['DatabaseDesireNextYear'].replace(to_replace = np.NaN, value = "unknown", inplace = True)
df['DatabaseWorkedWith'].replace(to_replace = np.NaN, value = "unknown", inplace = True)
df['DevType'].replace(to_replace = np.NaN, value = "not describes", inplace = True)
df['EdLevel'].replace(to_replace = np.NaN, value = "not describes", inplace = True)
df['Employment'].replace(to_replace = np.NaN, value = "not describes", inplace = True)

# %%
# remove NaN values vy None column NEW JO BHUNT REASEARCH
df.NEWJobHuntResearch = df.NEWJobHuntResearch.fillna(value='unspecified')
df.NEWLearn = df.NEWLearn.fillna(value='unspecified')
df.NEWOffTopic = df.NEWOffTopic.fillna(value='prefer not say')
df.NEWOnboardGood = df.NEWOnboardGood.fillna(value='not specified')
df.NEWOtherComms = df.NEWOtherComms.fillna(value='prefer not to say')
df.NEWOvertime = df.NEWOvertime.fillna(value='prefer not to say')
df.NEWPurchaseResearch = df.NEWPurchaseResearch.fillna(value='Other')
df.NEWPurpleLink = df.NEWPurpleLink.fillna(value='prefer not to say')
df.NEWSOSites = df.NEWSOSites.fillna(value='Other')
df.NEWStuck = df.NEWStuck.fillna(value='prefered not to say')
df.OpSys = df.OpSys.fillna(value= 'Other')
df.OrgSize = df.OrgSize.fillna(value = 'prefered not to say')
df.PlatformDesireNextYear = df.PlatformDesireNextYear.fillna(value='other')
df.PlatformWorkedWith = df.PlatformWorkedWith.fillna(value='other')
df.PurchaseWhat = df.PurchaseWhat.fillna(value='prefer not to say')

# %%
#Quels sont les caractéristiques (age, hobbies, Age1stCode, Country … ) des développeurs les plus riches.


#Avec quelles colonnes travailler (comment savoir quels sont les dev les plus riches : ) ?   ==> CompTotal et CompFreq
#problématique : il y a des dev qui ont une rentrée d'argent Weekly, Monthly, Yearly, comment faire pour définir les gens qui rapportent le plus
#Solution : Convertir toutes les rentrées d'argent en Yearly ==> Monthly * 11 (1 mois de congé/repos) , (Weekly*4)*11

# %%
pd.unique(df['MainBranch'])
# Out:
# array(['I am a developer by profession', 'I code primarily as a hobby',
#        'I used to be a developer by profession, but no longer am',
#        'I am not primarily a developer, but I write code sometimes as part of my work',
#        'I am a student who is learning to code', 'unspecified'],
#       dtype=object)

# %%
barWidth = 0.25

# %%
df.index[(df['CompFreq'] == 'Yearly') & (df['MainBranch'] == 'I am not primarily a developer, but I write code sometimes as part of my work')].shape[0]
# Out:
# 1856

# %%
df.index[(df['CompFreq'] == 'Monthly') & (df['MainBranch'] == 'I am not primarily a developer, but I write code sometimes as part of my work')].shape[0]
# Out:
# 1755

# %%
df.index[(df['CompFreq'] == 'Weekly') & (df['MainBranch'] == 'I am not primarily a developer, but I write code sometimes as part of my work')].shape[0]
# Out:
# 148

# %%
df.index[(df['CompFreq'] == 'Yearly') & (df['MainBranch'] == 'I am a developer by profession')].shape[0]
# Out:
# 17962

# %%
df.index[(df['CompFreq'] == 'Monthly') & (df['MainBranch'] == 'I am a developer by profession')].shape[0]
# Out:
# 17144

# %%
df.index[(df['CompFreq'] == 'Weekly') & (df['MainBranch'] == 'I am a developer by profession')].shape[0]
# Out:
# 1204

# %%
bars1 = [1856 , 17962]
bars2 = [1755 , 17144]
bars3 = [148 , 1204]

# %%
r1 = np.arange(len(bars1))
r2 = [x + barWidth for x in r1]
r3 = [x + barWidth for x in r2]

# %%
plt.figure(figsize= (12 , 15))
plt.bar(r1, bars1, color='#7f6d5f', width=barWidth, edgecolor='white', label='Yearly')
plt.bar(r2, bars2, color='#557f2d', width=barWidth, edgecolor='white', label='Monthly')
plt.bar(r3, bars3, color='#2d7f5e', width=barWidth, edgecolor='white', label='Weekly')

plt.xlabel('Répartition des dév par rapport à la fréquence de leurs revenues et leurs branches principales', fontweight='bold')
plt.xticks([r + barWidth for r in range(len(bars1))], ['Not a developer, but write code for my work', 'Developer by profession'])

plt.legend()
plt.show()

# %%
df['CompTotalYearly'] = np.where((df['CompFreq'] == 'Monthly') | (df['CompFreq'] == 'Weekly') , df['ConvertedComp'] * 11 , df['ConvertedComp'])

# %%
df['CompTotalYearly'] = np.where(df['CompFreq'] == 'Weekly' , (df['ConvertedComp'] * 4) * 11 , df['CompTotalYearly'])

# %%
df['CompTotalYearly'] = np.where(df['ConvertedComp'] == 'undefined' , 0 , df['CompTotalYearly'])

# %%
df['CompTotalYearly'].unique()
# Out:
# array(['nonenonenonenonenonenonenonenonenonenonenone', 'none', 116000.0,
#        ..., 369.0, 200.0, 38759.0], dtype=object)

# %%
np.size(df['Country'].unique())
# Out:
# 184

# %%
plt.figure(figsize= (40,40))
sns.barplot(
    y='MainBranch', 
    x='CompTotalYearly',
    data = df[['MainBranch' , 'Age' , 'Gender' , 'CompTotalYearly']][(df['CompTotalYearly'] != 0) & (df['Gender'] != 'Unspecified') & (df['CompTotalYearly'] != 'none')])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26576/2413565117.py in <module>
#       3     y='MainBranch',
#       4     x='CompTotalYearly',
# ----> 5     data = df[['MainBranch' , 'Age' , 'Gender' , 'CompTotalYearly']][(df['CompTotalYearly'] != 0) & (df['Gender'] != 'Unspecified') & (df['CompTotalYearly'] != 'none')])
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
# ...

# %%
#Les web framework les plus utilisés
#Colonnes utilisées : WebframeWorkedWith

# %%
df.groupby('WebframeWorkedWith').mean()
# Out:
#                                    WorkWeekHrs
# WebframeWorkedWith
# ASP.NET                              40.061453
# ASP.NET Core                         40.862069
# ASP.NET Core;Django                  46.318182
# ASP.NET Core;Django;Drupal;jQuery          NaN
# ASP.NET Core;Django;Express;Flask          NaN
# ...                                        ...
# jQuery;Spring;Symfony;Vue.js               NaN
# jQuery;Spring;Vue.js                 37.170213
# jQuery;Symfony                       40.831818
# jQuery;Symfony;Vue.js                40.413793
# jQuery;Vue.js                        39.766447
#
# [3790 rows x 1 columns]

# %%
df['WebframeDesireNextYear'][1]
# Out:
# 'ASP.NET Core'

# %%
Angular = (df['WebframeWorkedWith'].str.count('Angular').sum()) - (df['WebframeWorkedWith'].str.count('Angular.js').sum())
Angular_js = df['WebframeWorkedWith'].str.count('Angular.js').sum()

ASP_NET = (df['WebframeWorkedWith'].str.count('ASP.NET').sum()) - (df['WebframeWorkedWith'].str.count('ASP.NET Core').sum())
ASP_NET_Core = df['WebframeWorkedWith'].str.count('ASP.NET Core').sum()

Django = df['WebframeWorkedWith'].str.count('Django').sum()
Drupal = df['WebframeWorkedWith'].str.count('Drupal').sum()
Express = df['WebframeWorkedWith'].str.count('Express').sum()
Flask = df['WebframeWorkedWith'].str.count('Flask').sum()
Gatsby = df['WebframeWorkedWith'].str.count('Gatsby').sum()
jQuery = df['WebframeWorkedWith'].str.count('jQuery').sum()
Laravel = df['WebframeWorkedWith'].str.count('Laravel').sum()
React_js = df['WebframeWorkedWith'].str.count('React.js').sum()
Ruby_on_Rails = df['WebframeWorkedWith'].str.count('Ruby on Rails').sum()
Spring = df['WebframeWorkedWith'].str.count('Spring').sum()
Symfony = df['WebframeWorkedWith'].str.count('Symfony').sum()
Vue_js = df['WebframeWorkedWith'].str.count('Vue.js').sum()

# %%
df_web_framework = pd.DataFrame({
    'framework' : ['Angular' , 'Angular_js' , 'ASP_NET' , 'ASP_NET_Core' , 'Django' , 'Drupal' , 'Express' , 'Flask' , 'Gatsby' , 'jQuery' , 'Laravel' , 'React_js' , 'Spring' ,'Symfony' , 'Vue_js'],
    'values' : [Angular , Angular_js , ASP_NET ,ASP_NET_Core ,Django ,Drupal , Express,Flask , Gatsby,jQuery ,Laravel ,React_js , Spring,Symfony , Vue_js]
})

# %%
plt.figure(figsize= (15 , 10))
df_web_framework.sort_values(by = 'values' , ascending= True , inplace = True)
plt.barh(y = df_web_framework['framework'] , width= df_web_framework['values'] , color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.title('Framework web les plus utilisés')
# Out:
# Text(0.5, 1.0, 'Framework web les plus utilisés')

# %%
#Les web framework que les gens veulent utiliser les années prochaines
#Colonnes utilisées : WebframeDesireNextYear

# %%
Angular = (df['WebframeDesireNextYear'].str.count('Angular').sum()) - (df['WebframeDesireNextYear'].str.count('Angular.js').sum())
Angular_js = df['WebframeDesireNextYear'].str.count('Angular.js').sum()

ASP_NET = (df['WebframeDesireNextYear'].str.count('ASP.NET').sum()) - (df['WebframeDesireNextYear'].str.count('ASP.NET Core').sum())
ASP_NET_Core = df['WebframeDesireNextYear'].str.count('ASP.NET Core').sum()

Django = df['WebframeDesireNextYear'].str.count('Django').sum()
Drupal = df['WebframeDesireNextYear'].str.count('Drupal').sum()
Express = df['WebframeDesireNextYear'].str.count('Express').sum()
Flask = df['WebframeDesireNextYear'].str.count('Flask').sum()
Gatsby = df['WebframeDesireNextYear'].str.count('Gatsby').sum()
jQuery = df['WebframeDesireNextYear'].str.count('jQuery').sum()
Laravel = df['WebframeDesireNextYear'].str.count('Laravel').sum()
React_js = df['WebframeDesireNextYear'].str.count('React.js').sum()
Ruby_on_Rails = df['WebframeDesireNextYear'].str.count('Ruby on Rails').sum()
Spring = df['WebframeDesireNextYear'].str.count('Spring').sum()
Symfony = df['WebframeDesireNextYear'].str.count('Symfony').sum()
Vue_js = df['WebframeDesireNextYear'].str.count('Vue.js').sum()

# %%
df_web_framework_next = pd.DataFrame({
    'framework' : ['Angular' , 'Angular_js' , 'ASP_NET' , 'ASP_NET_Core' , 'Django' , 'Drupal' , 'Express' , 'Flask' , 'Gatsby' , 'jQuery' , 'Laravel' , 'React_js' , 'Spring' ,'Symfony' , 'Vue_js'],
    'values' : [Angular , Angular_js , ASP_NET ,ASP_NET_Core ,Django ,Drupal , Express,Flask , Gatsby,jQuery ,Laravel ,React_js , Spring,Symfony , Vue_js]
})

# %%
plt.figure(figsize= (15 , 10))
df_web_framework_next.sort_values(by = 'values' , ascending= True , inplace = True)
plt.barh(y = df_web_framework_next['framework'] , width= df_web_framework_next['values'] , color=(0.1, 0.1, 0.1, 0.1),  edgecolor='blue')
plt.title('Framework web desired next years')
# Out:
# Text(0.5, 1.0, 'Framework web desired next years')

# %%
#Les langages les plus utilisés
#Colonnes utilisées : LanguageWorkedWith

# %%
df.groupby('LanguageWorkedWith').mean()
# Out:
#                                                     WorkWeekHrs
# LanguageWorkedWith
# Assembly                                              40.000000
# Assembly;Bash/Shell/PowerShell                              NaN
# Assembly;Bash/Shell/PowerShell;C                      48.000000
# Assembly;Bash/Shell/PowerShell;C#;C++;Dart;Go;H...          NaN
# Assembly;Bash/Shell/PowerShell;C#;C++;Dart;Go;H...    80.000000
# ...                                                         ...
# Swift;TypeScript                                      40.000000
# Swift;VBA                                                   NaN
# TypeScript                                            43.900000
# TypeScript;VBA                                              NaN
# VBA                                                   40.931034
#
# [14257 rows x 1 columns]

# %%
#Combien de dev continue a apprendre de nouvelles techno?
#Colonnes utilisées : NEWLearn

# %%
df.shape
# Out:
# (64461, 59)

# %%
df.groupby('NEWLearn')['Age'].count()
# Out:
# NEWLearn
# Every few months        20938
# Once a decade            1241
# Once a year             20693
# Once every few years    13284
# unspecified              8305
# Name: Age, dtype: int64

# %%
few_months_prctg = df.groupby('NEWLearn')['Age'].count()[0]
once_decade_prctg = df.groupby('NEWLearn')['Age'].count()[1]
once_year_prctg = df.groupby('NEWLearn')['Age'].count()[2]
once_few_years_prctg = df.groupby('NEWLearn')['Age'].count()[3]
unspecified_prctg = df.groupby('NEWLearn')['Age'].count()[4]
list_learn = [few_months_prctg, once_decade_prctg, once_year_prctg, once_few_years_prctg, unspecified_prctg]

# %%
plt.figure(figsize=(13,13))
plt.pie(list_learn, labels= ['few_months_prctg', 'once_decade_prctg', 'once_year_prctg', 'once_few_years_prctg', 'unspecified_prctg'] ,labeldistance=1.15 , wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' })
plt.show()

# %%
df.groupby(['OpSys' , 'Age']).count()
# Out:
#                      MainBranch  Hobbyist  Age1stCode  CompFreq  CompTotal  \
# OpSys   Age
# BSD     22.0                  1         1           1         1          1
#         25.0                  3         3           3         3          3
#         26.0                  1         1           1         1          1
#         27.0                  1         1           1         1          1
#         28.0                  1         1           1         1          1
# ...                         ...       ...         ...       ...        ...
# Windows 94.0                  2         2           2         2          2
#         95.0                  1         1           1         1          1
#         96.0                  1         1           1         1          1
#         99.0                  3         3           3         3          3
#         unspecified        5862      5862        5862      5862       5862
#
# ...

# %%
#Proporition des OS utilisés par les dev.
#colonne utilisée : 
df['OpSys'].unique()
# Out:
# array(['Windows', 'MacOS', 'Linux-based', 'Other', 'BSD'], dtype=object)

# %%
os = {}
os[0] = df['OpSys'][df['OpSys'] == 'Windows'].count()
os[1] = df['OpSys'][df['OpSys'] == 'MacOS'].count()
os[2] = df['OpSys'][df['OpSys'] == 'Linux-based'].count()
os[3] = df['OpSys'][df['OpSys'] == 'Other'].count()
os[4] = df['OpSys'][df['OpSys'] == 'BSD'].count()

# %%
plt.figure(figsize= (10 , 10))
plt.bar(
    x = df['OpSys'].unique(),
    height = os.values()
           )
plt.show()

# %%
#Répartition des dev par rapport a leur niveau d’éducation.
plt.figure(figsize=(13,13))
plt.pie(df.groupby('EdLevel')['Age'].count().sort_values(ascending = False) , labels = df.groupby('EdLevel')['Age'].count().sort_values(ascending = False).index ,labeldistance=1.15 , wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' })
plt.show()

# %%
#Répartition des dév par rapport au type d’emploi.

# %%
df['DevType'].unique()
# Out:
# array(['Developer, desktop or enterprise applications;Developer, full-stack',
#        'Developer, full-stack;Developer, mobile', 'not describes', ...,
#        'Data scientist or machine learning specialist;Database administrator;Developer, back-end;Developer, front-end;System administrator',
#        'Academic researcher;Data or business analyst;Data scientist or machine learning specialist;Database administrator;Designer;Developer, back-end;Developer, desktop or enterprise applications;Developer, embedded applications or devices;Developer, front-end;Developer, full-stack;Developer, game or graphics;Developer, mobile;Developer, QA or test;DevOps specialist;Senior executive/VP;System administrator',
#        'Data or business analyst;Developer, mobile;Senior executive/VP;System administrator'],
#       dtype=object)

# %%
np.size(df['DevType'].unique())
# Out:
# 8270

# %%
# Répartition du salaire par rapport aux heures sup.
plt.figure(figsize=(10,10))
plt.pie(df.groupby('CompTotal')['CompFreq'].count().sort_values(ascending = False) , labels = df.groupby('CompTotal')['CompFreq'].count().sort_values(ascending = False).index ,labeldistance=1.15 , wedgeprops = { 'linewidth' : 3, 'edgecolor' : 'white' })
plt.show()

# %%
# Répartition des salaires en fonction des framework utilisés.

df.groupby('CompTotal')['WebframeWorkedWith'].count()
# Out:
# CompTotal
# 0.0                        104
# 1.0                         16
# 2.0                          3
# 3.0                          6
# 4.0                          4
#                          ...
# 1e+49                        1
# 1e+56                        1
# 1e+150                       1
# 1.11111111111111e+247        1
# undefined                29635
# Name: WebframeWorkedWith, Length: 3004, dtype: int64

# %%
# Répartition des salaires en fonction des pays.
df.groupby('CompTotal')['Country'].count()
# Out:
# CompTotal
# 0.0                        104
# 1.0                         16
# 2.0                          3
# 3.0                          6
# 4.0                          4
#                          ...
# 1e+49                        1
# 1e+56                        1
# 1e+150                       1
# 1.11111111111111e+247        1
# undefined                29246
# Name: Country, Length: 3004, dtype: int64

# %%
import matplotlib.pyplot as plt
pc_monthly = (df['CompFreq'] == 'Monthly').sum() * 100 / 64461
pc_yearly = (df['CompFreq'] == 'Yearly').sum() * 100 / 64461
pc_weekly= (df['CompFreq']== 'Weekly').sum() * 100/ 64461
pc_other = (df['CompFreq']== 'undefined').sum() * 100/ 64461

labels = ['Yearly', 'Monthly', 'Weekly', 'Other']
data = [pc_yearly,pc_monthly,pc_weekly,pc_other]
colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(10,5), dpi=80)
plt.pie(data, labels = labels,autopct='%.0f%%',colors=colors)
plt.show()

# %%
import matplotlib.pyplot as plt
pc_monthly = (df['CompFreq'] == 'Monthly').sum() * 100 / 64461
pc_yearly = (df['CompFreq'] == 'Yearly').sum() * 100 / 64461
pc_weekly= (df['CompFreq']== 'Weekly').sum() * 100/ 64461
pc_other = (df['CompFreq']== 'undefined').sum() * 100/ 64461

labels = ['Yearly', 'Monthly', 'Weekly']
data = [pc_yearly,pc_monthly,pc_weekly]
colors = sns.color_palette('pastel')[0:5]
plt.figure(figsize=(10,5), dpi=80)
plt.pie(data, labels = labels,autopct='%.0f%%',colors=colors)
plt.show()

# %%
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator

text = " ".join(review for review in df.JobFactors.astype(str))
stopwords = set(STOPWORDS)
stopwords.update(['and',';',',','in','at','and','work','working','d'])
wordcloud = WordCloud(stopwords=stopwords, background_color="white", width=800, height=400).generate(text)
plt.figure( figsize=(20,8) )
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis("off")
plt.show()

# %%
pc_y = (df.NEWDevOps == 'Yes').sum() * 100 / 64461
pc_n = (df.NEWDevOps == 'No').sum() * 100 / 64461
pc_nn = (df.NEWDevOps == 'None').sum() * 100 / 64461
pc_ns = (df.NEWDevOps == 'Not sure').sum() * 100 / 64461
labels = ['YES','NO','Not Sure','None']
data = [pc_y,pc_n,pc_ns,pc_nn]
plt.figure(figsize=(10,8), dpi=80)
plt.title('Presence Devops in Company ')
plt.pie(data, labels = labels,autopct='%.0f%%')
plt.show()

# %%
nb_fullTime = ((df.Employment == 'Employed full-time') & (df.MainBranch == 'I am a developer by profession')).sum()
nb_student = ((df.Employment == 'Student') & (df.MainBranch == 'I am a developer by profession')).sum()
nb_looking = ((df.Employment == 'Not employed, but looking for work') & (df.MainBranch == 'I am a developer by profession')).sum()
nb_notDesc = ((df.Employment == 'not describes') & (df.MainBranch == 'I am a developer by profession')).sum()
nb_independant = ((df.Employment == 'Independent contractor, freelancer, or self-employed') & (df.MainBranch == 'I am a developer by profession')).sum()

# %%
bar = pd.DataFrame({'lab':['Employed full time', 'Student', 'Looking for job', 'Independant','not describes'], 'Job Title':[nb_fullTime,nb_student,nb_looking,nb_notDesc,nb_independant]})
bar.plot.bar(x='lab', y='Job Title', rot=0,figsize=(10,5),title='Developer Employment Status')
# Out:
# <AxesSubplot:title={'center':'Developer Employment Status'}, xlabel='lab'>

# %%
# master's degree states 
df1 = pd.DataFrame({'FormalEd': df.EdLevel , 'Employment' : df.Employment})
nb_masterlookingforwork = (df1.Employment == 'Not employed, but looking for work').sum() & (df1.FormalEd == 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)').sum()
nb_masteremployed = (df1.Employment == 'Employed full-time').sum() & (df1.FormalEd == 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)').sum()
nb_Masterndependant = (df1.Employment == 'Independent contractor, freelancer, or self-employed').sum() & (df1.FormalEd == 'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)').sum()

# %%
bar = pd.DataFrame({'lab':['Employed full time', 'Looking for job', 'Independant'], "Job Title":[nb_masteremployed,nb_masterlookingforwork,nb_Masterndependant]})
bar.plot.bar(x='lab', y="Job Title", rot=0,figsize=(10,5),title='Master Degree Employment Status')
# Out:
# <AxesSubplot:title={'center':'Master Degree Employment Status'}, xlabel='lab'>

# %%
nb_bachelorlookingforwork = (df1.Employment == 'Not employed, but looking for work').sum() (df1.FormalEd == "Bachelor’s degree (B.A., B.S., B.Eng., etc.)"& (df.MainBranch == 'I am a developer by profession')).sum()
nb_bacheoremployed = (df1.Employment == 'Employed full-time').sum() & (df1.FormalEd == "Bachelor’s degree (B.A., B.S., B.Eng., etc.)" & (df.MainBranch == 'I am a developer by profession')).sum()
nb_bachelorindependant = (df1.Employment == 'Independent contractor, freelancer, or self-employed').sum() & (df1.FormalEd == "Bachelor’s degree (B.A., B.S., B.Eng., etc.)"& (df.MainBranch == 'I am a developer by profession')).sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     315             try:
# ...

# %%
bar = pd.DataFrame({'lab':['Employed full time', 'Looking for job', 'Independant'], "Job Title":[nb_bacheoremployed,nb_bachelorlookingforwork,nb_bachelorindependant]})
bar.plot.bar(x='lab', y="Job Title", rot=0,figsize=(10,5),title='Bachelor Degree Employment Status')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26576/3469361258.py in <module>
# ----> 1 bar = pd.DataFrame({'lab':['Employed full time', 'Looking for job', 'Independant'], "Job Title":[nb_bacheoremployed,nb_bachelorlookingforwork,nb_bachelorindependant]})
#       2 bar.plot.bar(x='lab', y="Job Title", rot=0,figsize=(10,5),title='Bachelor Degree Employment Status')
#
# NameError: name 'nb_bacheoremployed' is not defined

# %%
df1.head(30)
# Out:
#                                                      FormalEd  \
# Respondent
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 3                                               not describes
# 4             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 5                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 6           Secondary school (e.g. American high school, G...
# 7                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 8                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 9                          Professional degree (JD, MD, etc.)
# 10            Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 11               Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 12          Some college/university study without earning ...
# 13          Secondary school (e.g. American high school, G...
# 14                        Associate degree (A.A., A.S., etc.)
# ...

# %%
nb_bachelorlookingforwork = (df1.Employment == 'Not employed, but looking for work').sum() (df1.FormalEd == "Bachelor’s degree (B.A., B.S., B.Eng., etc.)"& (df.MainBranch == 'I am a developer by profession')).sum()
nb_bacheoremployed = (df1.Employment == 'Employed full-time').sum() & (df1.FormalEd == "Bachelor’s degree (B.A., B.S., B.Eng., etc.)" & (df.MainBranch == 'I am a developer by profession')).sum()
nb_bachelorindependant = (df1.Employment == 'Independent contractor, freelancer, or self-employed').sum() & (df1.FormalEd == "Bachelor’s degree (B.A., B.S., B.Eng., etc.)"& (df.MainBranch == 'I am a developer by profession')).sum()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     301         #  (xint or xbool) and (yint or bool)
# --> 302         result = op(x, y)
#     303     except TypeError:
#
# ~\anaconda3\lib\site-packages\pandas\core\roperator.py in rand_(left, right)
#      51 def rand_(left, right):
# ---> 52     return operator.and_(right, left)
#      53
#
# TypeError: ufunc 'bitwise_and' not supported for the input types, and the inputs could not be safely coerced to any supported types according to the casting rule ''safe''
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\ops\array_ops.py in na_logical_op(x, y, op)
#     315             try:
# ...

# %%
bar = pd.DataFrame({'lab':['Employed full time', 'Looking for job', 'Independant'], "Job Title":[nb_bacheoremployed,nb_bachelorlookingforwork,nb_bachelorindependant]})
bar.plot.bar(x='lab', y="Job Title", rot=0,figsize=(10,5),title='Bachelor Degree Employment Status')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26576/3469361258.py in <module>
# ----> 1 bar = pd.DataFrame({'lab':['Employed full time', 'Looking for job', 'Independant'], "Job Title":[nb_bacheoremployed,nb_bachelorlookingforwork,nb_bachelorindependant]})
#       2 bar.plot.bar(x='lab', y="Job Title", rot=0,figsize=(10,5),title='Bachelor Degree Employment Status')
#
# NameError: name 'nb_bacheoremployed' is not defined

# %%
df.YearsCodePro.fillna(value='None ',inplace=True)

# %%
df2 = pd.DataFrame({'MainBranch' : df.MainBranch  , 'YearsCodePro' : df.YearsCodePro ,'EdLevel':df.EdLevel})
df2
# Out:
#                                                    MainBranch  \
# Respondent
# 1                              I am a developer by profession
# 2                              I am a developer by profession
# 3                                 I code primarily as a hobby
# 4                              I am a developer by profession
# 5           I used to be a developer by profession, but no...
# ...                                                       ...
# 64858                                             unspecified
# 64867                                             unspecified
# 64898                                             unspecified
# 64925                                             unspecified
# 65112                                             unspecified
#
#                 YearsCodePro                                          EdLevel
# Respondent
# 1                         27  Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# ...

# %%
x = df2.loc[(df2.MainBranch == 'I am a developer by profession' ) & (df2.YearsCodePro != 'Prefer Not To Say ') & (df2.EdLevel)]
x
df3 = pd.DataFrame(x)

# %%
sns.set(rc = {'figure.figsize':(20,8)})
sns.barplot(x="MainBranch", by="YearsCodePro", hue="EdLevel", data=df3)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26576/392924898.py in <module>
#       1 sns.set(rc = {'figure.figsize':(20,8)})
# ----> 2 sns.barplot(x="MainBranch", by="YearsCodePro", hue="EdLevel", data=df3)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
# ...

# %%
df3
# Out:
#                                 MainBranch      YearsCodePro  \
# Respondent
# 1           I am a developer by profession                27
# 2           I am a developer by profession                 4
# 4           I am a developer by profession                 4
# 6           I am a developer by profession                 4
# 7           I am a developer by profession                 4
# ...                                    ...               ...
# 65631       I am a developer by profession  Less than 1 year
# 65632       I am a developer by profession             None
# 65634       I am a developer by profession             None
# 65635       I am a developer by profession  Less than 1 year
# 65636       I am a developer by profession             None
#
#                                                       EdLevel
# Respondent
# 1             Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 2                Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# ...

# %%
# replace str to actuall value
df3.YearsCodePro = df3.YearsCodePro.replace(['Less than 1 year'],'1')
df3.YearsCodePro = df3.YearsCodePro.replace(['More than 50 years'],'50')

# %%
df3.YearsCodePro = df3.YearsCodePro.astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26576/1988287336.py in <module>
# ----> 1 df3.YearsCodePro = df3.YearsCodePro.astype(int)
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in astype(self, dtype, copy, errors)
#    5813         else:
#    5814             # else, only a single dtype is given
# -> 5815             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    5816             return self._constructor(new_data).__finalize__(self, method="astype")
#    5817
#
# ~\anaconda3\lib\site-packages\pandas\core\internals\managers.py in astype(self, dtype, copy, errors)
#     416
#     417     def astype(self: T, dtype, copy: bool = False, errors: str = "raise") -> T:
# --> 418         return self.apply("astype", dtype=dtype, copy=copy, errors=errors)
#     419
#     420     def convert(
#
# ...

# %%
sns.set(rc = {'figure.figsize':(10,10)})
sns.barplot(x="MainBranch", y="YearsCodePro", hue="EdLevel", data=df3).set_title("Years Experience Based on Education Level")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26576/1107234602.py in <module>
#       1 sns.set(rc = {'figure.figsize':(10,10)})
# ----> 2 sns.barplot(x="MainBranch", y="YearsCodePro", hue="EdLevel", data=df3).set_title("Years Experience Based on Education Level")
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3183                           estimator, ci, n_boot, units, seed,
# ...

# %%
# % des devs qui codent dans leur temps libre :
dfDev = df[df["MainBranch"] == "I am a developer by profession"]
nb_cells = np.product(dfDev["Hobbyist"].shape)
devHobby = (dfDev["Hobbyist"] == "Yes")
sumDevHobby = devHobby.sum().sum()
sumDevHobby / nb_cells * 100
# Out:
# 76.95632826902295

# %%
plt.figure(figsize=(10 , 10))
plt.pie(dfDev["Hobbyist"] , labeldistance=1.15, wedgeprops = { 'linewidth' : 6, 'edgecolor' : 'white' } , autopct='%1.1f%%' )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26576/1601162367.py in <module>
#       1 plt.figure(figsize=(10 , 10))
# ----> 2 plt.pie(dfDev["Hobbyist"] , labeldistance=1.15, wedgeprops = { 'linewidth' : 6, 'edgecolor' : 'white' } , autopct='%1.1f%%' )
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3011         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    3012         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
# -> 3013         **({"data": data} if data is not None else {}))
#    3014
#    3015
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
plt.figure(figsize=(10 , 10))
plt.pie(devHobby , labeldistance=1.15, wedgeprops = { 'linewidth' : 6, 'edgecolor' : 'white' } , autopct='%1.1f%%' )
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26576/1218809190.py in <module>
#       1 plt.figure(figsize=(10 , 10))
# ----> 2 plt.pie(devHobby , labeldistance=1.15, wedgeprops = { 'linewidth' : 6, 'edgecolor' : 'white' } , autopct='%1.1f%%' )
#       3 plt.show()
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, center, frame, rotatelabels, normalize, data)
#    3011         wedgeprops=wedgeprops, textprops=textprops, center=center,
#    3012         frame=frame, rotatelabels=rotatelabels, normalize=normalize,
# -> 3013         **({"data": data} if data is not None else {}))
#    3014
#    3015
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
dfAge = df[df["Age"] != "unspecified"]
plt.figure(figsize = (20, 10))
sns.lineplot(x="OrgSize", y=dfAge["Age"], hue="NEWOnboardGood", data=df)
# Out:
# <AxesSubplot:xlabel='OrgSize', ylabel='Age'>

# %%
dfDev = df[df["MainBranch"] == "I am a developer by profession"]

dfDev = dfDev[dfDev["Age1stCode"] != "unspecified"]

dfDev = dfDev[dfDev["ConvertedComp"] != "none"]

dfDev["Age1stCode"] = pd.to_numeric(dfDev["Age1stCode"])



dfDevEarly = dfDev[dfDev["Age1stCode"] < 18]

dfDevNorm = dfDev[dfDev["Age1stCode"] >= 18]


# Devs salaire par rapport à l'age où ils ont codé la 1ere fois
plt.figure(figsize=(100,50))
graphDevSalaryPerAge = sns.lineplot(data=dfDev , x = dfDev['Age1stCode'] , y = dfDev['ConvertedComp'])
plt.xticks(rotation=90)
graphDevSalaryPerAge
# Out:
# <AxesSubplot:xlabel='Age1stCode', ylabel='ConvertedComp'>

# %%
plt.figure(figsize=(100,50))
graphDevSalaryPerAge = sns.lineplot(data=dfDev , x = dfDevEarly['Age1stCode'] , y = dfDevEarly['ConvertedComp'])
plt.xticks(rotation=90)
graphDevSalaryPerAge
# Out:
# <AxesSubplot:xlabel='Age1stCode', ylabel='ConvertedComp'>

# %%
plt.figure(figsize=(100,50))
graphDevSalaryPerAge = sns.lineplot(data=dfDev , x = dfDevNorm['Age1stCode'] , y = dfDevNorm['ConvertedComp'])
plt.xticks(rotation=90)
graphDevSalaryPerAge
# Out:
# <AxesSubplot:xlabel='Age1stCode', ylabel='ConvertedComp'>

# %%
dfDevEarly.describe()
# Out:
#          Age1stCode   WorkWeekHrs
# count  23044.000000  22391.000000
# mean      12.997136     40.310124
# std        2.932886     12.098764
# min        3.000000      1.000000
# 25%       11.000000     39.000000
# 50%       14.000000     40.000000
# 75%       15.000000     42.000000
# max       17.000000    168.000000

# %%
dfDevNorm.describe()
# Out:
#         Age1stCode  WorkWeekHrs
# count  8457.000000  8138.000000
# mean     20.737732    40.376765
# std       3.922503    14.025077
# min      18.000000     1.000000
# 25%      18.000000    40.000000
# 50%      19.000000    40.000000
# 75%      22.000000    44.000000
# max      85.000000   168.000000

# %%
df = df[df["CurrencySymbol"] != "undefined"]

df = df[df["ConvertedComp"] != "none"]

dfConverted = df["ConvertedComp"]

sns.catplot(x="Gender", y=dfConverted, hue = "CurrencySymbol", kind="bar", data=df)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_26576/920554424.py in <module>
#       5 dfConverted = df["ConvertedComp"]
#       6
# ----> 7 sns.catplot(x="Gender", y=dfConverted, hue = "CurrencySymbol", kind="bar", data=df)
#
# ~\anaconda3\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ~\anaconda3\lib\site-packages\seaborn\categorical.py in catplot(x, y, hue, data, row, col, col_wrap, estimator, ci, n_boot, units, seed, order, hue_order, row_order, col_order, kind, height, aspect, orient, color, palette, legend, legend_out, sharex, sharey, margin_titles, facet_kws, **kwargs)
#    3845
#    3846     # Draw the plot onto the facets
# ...
